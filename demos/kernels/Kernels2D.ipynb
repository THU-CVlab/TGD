# %% [markdown]
# #  Demos for how to get TGD kenels for two-dimentional usage

# %%
# get the TGD lib
! pip install -i https://test.pypi.org/simple/ TGD==0.9.1

from TGD import TGDkernel

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# ...

# %% [markdown]
# ## Two-dimensional first-order derivatives TGD by Orthogonal construction method

# %%
radius = 7
semi_width = 7
theta = 30   # kernel angle
gauss_param = {'delta': 2.4}

tgd = TGDkernel()

# %%
xv,yv, kernel = tgd.getKernel2D(radius= radius, 
                                method = 'directional',
                                kernel_size=141, 
                                theta = theta, 
                                paramx = gauss_param, paramy = gauss_param, 
                                kernel_func = 'Gaussian')
print(xv.shape,yv.shape, kernel.shape)
print(np.min(kernel),np.max(kernel))
# Out:
# (141, 141) (141, 141) (141, 141)
# -1.0 1.0

# %%
fig = plt.figure(figsize=(4, 4), dpi=100)
ax = fig.add_axes(Axes3D(fig))
surf = ax.plot_surface(xv,yv, kernel,
                       rstride=1,  # rstride（row）
                       cstride=1,  # cstride(column)=
                       cmap='rainbow',
                       )
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()

# %% [markdown]
# ## Two-dimensional second-order derivatives TGD by Orthogonal construction method

# %%
radius = 7
kernel_size=141
gauss_param = {'delta': 2.4}
xv,yv, kernel = tgd.getKernel2D(radius= radius, 
                                method = 'directional',
                                kernel_size=kernel_size, 
                                theta = theta, 
                                derivation_order = 2,
                                paramx = gauss_param, paramy = gauss_param, 
                                kernel_func = 'Gaussian')
print(xv.shape,yv.shape, kernel.shape)
print(np.min(kernel),np.max(kernel))
print(kernel.sum())
# Out:
# (141, 141) (141, 141) (141, 141)
# -1.0 0.028095530647113367
# 3.552713678800501e-15

# %%
fig = plt.figure(figsize=(4, 4), dpi=100)
ax = fig.add_axes(Axes3D(fig)) 
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
surf = ax.plot_surface(xv,yv, kernel, rstride = 1, cstride = 1, cmap='rainbow')
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()

# %%
radius = 1
kernel_size= 5
gauss_param = {'delta': 1}
xv,yv, kernel = tgd.getKernel2D(radius= radius, 
                                method = 'directional',
                                kernel_size=kernel_size, 
                                theta = theta, 
                                derivation_order = 2,
                                paramx = gauss_param, paramy = gauss_param, 
                                kernel_func = 'Gaussian')
print(xv.shape,yv.shape, kernel.shape)
print(np.min(kernel),np.max(kernel))
# Out:
# (5, 5) (5, 5) (5, 5)
# -1.0 0.06498807614450963

# %%
fig = plt.figure(figsize=(4, 4), dpi=100)
ax = fig.add_axes(Axes3D(fig)) 
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
surf = ax.plot_surface(xv,yv, kernel, rstride = 1, cstride = 1, cmap='rainbow')
fig.colorbar(surf, shrink=0.5, aspect=15)
plt.show()

# %% [markdown]
# ## Two-dimensional first-order derivatives TGD by Rotational construction method

# %%
radius = 7
kernel_size= 141
theta = 0
gauss_param = {'delta': 2.4}
exp_param = {'k': 1, 'delta': 0.56}
xv,yv, kernel = tgd.getKernel2D(radius= radius, 
                                method = 'rotational',
                                kernel_size=kernel_size, 
                                theta = theta, 
                                derivation_order = 1,
                                paramx = gauss_param, paramy = gauss_param, 
                                kernel_func = 'Gaussian'
                                # paramx = exp_param, paramy = exp_param, 
                                # kernel_func = 'Exp'
                                )
print(xv.shape,yv.shape, kernel.shape)
print(np.min(kernel),np.max(kernel))
# Out:
# (141, 141) (141, 141) (141, 141)
# -1.0 0.9999999999999963

# %%
fig = plt.figure(figsize=(4, 4), dpi=100)
ax = fig.add_axes(Axes3D(fig)) 
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
surf = ax.plot_surface(xv,yv, kernel, rstride = 1, cstride = 1, cmap='rainbow')
fig.colorbar(surf, shrink=0.5, aspect=10)
plt.show()

# %%
radius = 7
kernel_size= 141
theta = 0
gauss_param = {'delta': 2.4}
exp_param = {'k': 1, 'delta': 0.56}
xv,yv, kernel = tgd.getKernel2D(radius= radius, 
                                method = 'rotational',
                                kernel_size=kernel_size, 
                                theta = theta, 
                                interp_step = 0.0001,
                                derivation_order = 2,
                                paramx = exp_param, paramy = exp_param, 
                                kernel_func = 'Exp'
                                # paramx = gauss_param, paramy = gauss_param, 
                                # kernel_func = 'Gaussian'
                                )
print(xv.shape,yv.shape, kernel.shape)
print(np.min(kernel),np.max(kernel))
print(kernel.sum())
# Out:
# a:  1.0736300737335114e-11
# (141, 141) (141, 141) (141, 141)
# -1.0 9.802263424575865e-05
# 1.6653345369377348e-16

# %%
fig = plt.figure(figsize=(4, 4), dpi=100)
ax = fig.add_axes(Axes3D(fig)) 
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
surf = ax.plot_surface(xv,yv, kernel, rstride = 1, cstride = 1, cmap='rainbow')
# fig.colorbar(surf, shrink=0.5, aspect=10)
plt.show()

# %%
radius = 6
kernel_size= 13
theta = 0
gauss_param = {'delta': 2}
exp_param = {'k': 1, 'delta': 0.56}
xv,yv, kernel = tgd.getKernel2D(radius= radius, 
                                method = 'rotational',
                                kernel_size=kernel_size, 
                                theta = theta, 
                                interp_step = 0.0001,
                                derivation_order = 2,
                                # paramx = exp_param, paramy = exp_param, 
                                # kernel_func = 'Exp'
                                paramx = gauss_param, paramy = gauss_param, 
                                kernel_func = 'Gaussian'
                                )
print(xv.shape,yv.shape, kernel.shape)
print(np.min(kernel),np.max(kernel))
print(kernel.sum())
print(kernel[6,6])
# Out:
# a:  4.017665028790973e-10
# (13, 13) (13, 13) (13, 13)
# -1.0 0.005982045543415852
# 3.885780586188048e-16
# -1.0

# %%
fig = plt.figure(figsize=(4, 4), dpi=100)
ax = fig.add_axes(Axes3D(fig)) 
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
surf = ax.plot_surface(xv,yv, kernel, rstride = 1, cstride = 1, cmap='rainbow')
# fig.colorbar(surf, shrink=0.5, aspect=10)
plt.show()
